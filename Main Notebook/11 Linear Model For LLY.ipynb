# %% [markdown]
# # LLY (Eli Lilly and Company)

# %% [markdown]
# ### Importing Necessary Libraries for Machine Learning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# ### Loading the Data

# %%
df=pd.read_csv('Data Set.csv')
df=pd.DataFrame(df)

# %%
df=df.iloc[23055:]
df
# Out:
#              Date Ticker        Open        High         Low       Close  \
# 23055  2015-01-02    LLY   69.769997   70.820000   69.720001   70.059998
# 23056  2015-01-05    LLY   69.730003   70.089996   69.150002   69.370003
# 23057  2015-01-06    LLY   69.919998   70.910004   69.199997   69.720001
# 23058  2015-01-07    LLY   70.029999   70.529999   68.449997   69.230003
# 23059  2015-01-08    LLY   70.000000   71.489998   69.660004   70.870003
# ...           ...    ...         ...         ...         ...         ...
# 25481  2024-08-23    LLY  955.440002  960.500000  943.109985  952.739990
# 25482  2024-08-26    LLY  949.200012  955.000000  942.770020  950.530029
# 25483  2024-08-27    LLY  952.500000  972.479980  949.950012  954.479980
# 25484  2024-08-28    LLY  954.150024  958.340027  943.260010  948.940002
# 25485  2024-08-29    LLY  955.000000  957.520020  936.000000  940.200012
#
#         Adj Close   Volume
# 23055   58.001339  3146200
# 23056   57.430111  4845500
# 23057   57.719872  5127400
# 23058   57.314201  9043000
# 23059   58.671932  7472200
# ...           ...      ...
# 25481  952.739990  2063300
# 25482  950.530029  2166000
# 25483  954.479980  2912900
# 25484  948.940002  1701800
# 25485  940.200012  1762200
#
# [2431 rows x 8 columns]

# %% [markdown]
# ### Visualizing Features and Target Data

# %%
plt.plot(df['Open'],label='Opening Price')
plt.plot(df['Close'],label='Closing price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock price (Open vs Close Prices)')
plt.legend()
plt.show()

# %% [markdown]
# ### Splitting the Dataset for Training and Testing

# %%
X=df[['Open','High','Low']]
y=df[['Close']]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=42)

# %% [markdown]
# ### Creating and Training the Model

# %%
Model=LinearRegression()
Model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Make Predictions by using test data

# %%
y_pred=Model.predict(X_test)

# %% [markdown]
# ### Evaluate the Model

# %%
mse=mean_squared_error(y_pred,y_test)
r2=r2_score(y_pred,y_test)
print('MSE:',mse)
print('Accuracy:',int(r2*100),'%')
# Out:
# MSE: 3.017662742241295
# Accuracy: 99 %

# %% [markdown]
# ### Visualizing Actual and Prdicated Data

# %%
a=np.array([i for i in range(1,len(y_test)+1)])
plt.scatter(a,np.array(y_test),color='#4285F4',label='Acutal Price')
plt.scatter(a,np.array(y_pred),color='#0F9D58',label='Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Actual vs. Predicted Data')
plt.legend()
plt.show()

# %% [markdown]
# ### Project Summary:
#
# * Model Performance: The Linear Regression model achieved a remarkable 99% accuracy in predicting closing prices, demonstrating its effectiveness in stock price forecasting.
