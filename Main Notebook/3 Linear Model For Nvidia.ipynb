# %% [markdown]
# # NVIDIA Corporation

# %% [markdown]
# ### Importing Necessary Libraries for Machine Learning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# ### Loading the Data

# %%
df=pd.read_csv('Data Set.csv')
df=pd.DataFrame(df)

# %%
df=df.iloc[4862:7293]
df
# Out:
#             Date Ticker        Open        High         Low       Close  \
# 4862  2015-01-02   NVDA    0.503250    0.507000    0.495250    0.503250
# 4863  2015-01-05   NVDA    0.503250    0.504750    0.492500    0.494750
# 4864  2015-01-06   NVDA    0.495500    0.496000    0.479250    0.479750
# 4865  2015-01-07   NVDA    0.483250    0.487500    0.477000    0.478500
# 4866  2015-01-08   NVDA    0.484000    0.499500    0.483750    0.496500
# ...          ...    ...         ...         ...         ...         ...
# 7288  2024-08-23   NVDA  125.860001  129.600006  125.220001  129.369995
# 7289  2024-08-26   NVDA  129.570007  131.259995  124.370003  126.459999
# 7290  2024-08-27   NVDA  125.050003  129.199997  123.879997  128.300003
# 7291  2024-08-28   NVDA  128.119995  128.330002  122.639999  125.610001
# 7292  2024-08-29   NVDA  121.360001  124.430000  116.709999  117.589996
#
#        Adj Close     Volume
# 4862    0.483218  113680000
# 4863    0.475056  197952000
# 4864    0.460654  197764000
# 4865    0.459453  321808000
# 4866    0.476737  283780000
# ...          ...        ...
# 7288  129.369995  323230300
# 7289  126.459999  331964700
# 7290  128.300003  303134600
# 7291  125.610001  448101100
# 7292  117.589996  451799100
#
# [2431 rows x 8 columns]

# %% [markdown]
# ### Visualizing Features and Target Data

# %%
plt.plot(df['Open'],label='Opening Price')
plt.plot(df['Close'],label='Closing price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock price (Open vs Close Prices)')
plt.legend()
plt.show()

# %% [markdown]
# ### Model Development Process

# %%
X=df[['Open','High','Low']]
y=df[['Close']]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=42)

# %% [markdown]
# ### Creating and Training the Model

# %%
Model=LinearRegression()
Model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Make Predictions by using test data

# %%
y_pred=Model.predict(X_test)

# %% [markdown]
# ### Evaluate the Model

# %%
mse=mean_squared_error(y_pred,y_test)
r2=r2_score(y_pred,y_test)
print('MSE:',mse)
print('Accuracy:',int(r2*100),'%')
# Out:
# MSE: 0.13199471893716033
# Accuracy: 99 %

# %% [markdown]
# ### Visualizing Actual and Prdicated Data

# %%
a=np.array([i for i in range(1,488)])
plt.scatter(a,np.array(y_test),color='#4285F4',label='Acutal Price')
plt.scatter(a,np.array(y_pred),color='#0F9D58',label='Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Actual vs. Predicted Data')
plt.legend()
plt.show()

# %% [markdown]
# ### Project Summary:
#
# * Model Performance: The Linear Regression model achieved a remarkable 99% accuracy in predicting closing prices, demonstrating its effectiveness in stock price forecasting.
