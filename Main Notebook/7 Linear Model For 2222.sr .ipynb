# %% [markdown]
# # SAUDI ARABIAN OIL COMPANY

# %% [markdown]
# ### Importing Necessary Libraries for Machine Learning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# ### Loading the Data

# %%
df=pd.read_csv('Data Set.csv')
df=pd.DataFrame(df)

# %%
df=df.iloc[14586:15762] 
df
# Out:
#              Date   Ticker       Open       High        Low      Close  \
# 14586  2019-12-11  2222.SR  29.090908  29.090908  29.090908  29.090908
# 14587  2019-12-12  2222.SR  31.983471  31.983471  29.752066  30.413223
# 14588  2019-12-15  2222.SR  30.661158  30.991735  30.413223  30.909090
# 14589  2019-12-16  2222.SR  30.991735  31.487602  30.991735  31.404959
# 14590  2019-12-17  2222.SR  31.446280  31.528925  30.991735  31.198347
# ...           ...      ...        ...        ...        ...        ...
# 15757  2024-08-25  2222.SR  27.750000  27.850000  27.700001  27.850000
# 15758  2024-08-26  2222.SR  27.850000  28.000000  27.799999  27.950001
# 15759  2024-08-27  2222.SR  27.950001  28.049999  27.850000  27.850000
# 15760  2024-08-28  2222.SR  27.799999  27.850000  27.650000  27.750000
# 15761  2024-08-29  2222.SR  27.750000  27.950001  27.700001  27.950001
#
#        Adj Close     Volume
# 14586  24.935045   38289394
# 14587  26.068457  505692621
# 14588  26.493484   98349281
# 14589  26.918514  105973907
# 14590  26.741415  142672245
# ...          ...        ...
# 15757  27.850000    8706710
# 15758  27.950001   14857870
# 15759  27.850000   18005073
# 15760  27.750000   15561397
# 15761  27.950001   74726722
#
# [1176 rows x 8 columns]

# %% [markdown]
# ### Visualizing Features and Target Data

# %%
plt.plot(df['Open'],label='Opening Price')
plt.plot(df['Close'],label='Closing price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock price (Open vs Close Prices)')
plt.legend()
plt.show()

# %% [markdown]
# ### Model Development Process

# %%
X=df[['Open','High','Low']]
y=df[['Close']]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=42)

# %% [markdown]
# ### Creating and Training the Model

# %%
Model=LinearRegression()
Model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Make Predictions by using test data

# %%
y_pred=Model.predict(X_test)

# %% [markdown]
# ### Evaluate the Model

# %%
mse=mean_squared_error(y_pred,y_test)
r2=r2_score(y_pred,y_test)
print('MSE:',mse)
print('Accuracy:',int(r2*100),'%')
# Out:
# MSE: 0.015296198433503026
# Accuracy: 99 %

# %% [markdown]
# ### Visualizing Actual and Prdicated Data

# %%
a=np.array([i for i in range(1,len(y_test)+1)])
plt.scatter(a,np.array(y_test),color='#4285F4',label='Acutal Price')
plt.scatter(a,np.array(y_pred),color='#0F9D58',label='Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Actual vs. Predicted Data')
plt.legend()
plt.show()

# %% [markdown]
# ### Project Summary:
#
# * Model Performance: The Linear Regression model achieved a remarkable 99% accuracy in predicting closing prices, demonstrating its effectiveness in stock price forecasting.
