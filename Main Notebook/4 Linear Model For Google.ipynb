# %% [markdown]
# # GOOGL Alphabet Inc.

# %% [markdown]
# ### Importing Necessary Libraries for Machine Learning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# ### Loading the Data

# %%
df=pd.read_csv('Data Set.csv')
df=pd.DataFrame(df)

# %%
df=df.iloc[7293:9724]
df
# Out:
#             Date Ticker        Open        High         Low       Close  \
# 7293  2015-01-02  GOOGL   26.629999   26.790001   26.393999   26.477501
# 7294  2015-01-05  GOOGL   26.357500   26.399500   25.887501   25.973000
# 7295  2015-01-06  GOOGL   26.025000   26.060499   25.277500   25.332001
# 7296  2015-01-07  GOOGL   25.547501   25.574499   25.182501   25.257500
# 7297  2015-01-08  GOOGL   25.075500   25.375000   24.750999   25.345501
# ...          ...    ...         ...         ...         ...         ...
# 9719  2024-08-23  GOOGL  164.720001  166.179993  163.830002  165.619995
# 9720  2024-08-26  GOOGL  166.380005  167.550003  164.460007  166.160004
# 9721  2024-08-27  GOOGL  165.839996  166.440002  164.460007  164.679993
# 9722  2024-08-28  GOOGL  165.039993  165.600006  161.529999  162.850006
# 9723  2024-08-29  GOOGL  164.309998  165.970001  160.250000  161.779999
#
#        Adj Close    Volume
# 7293   26.447147  26480000
# 7294   25.943224  41182000
# 7295   25.302961  54456000
# 7296   25.228544  46918000
# 7297   25.316446  73054000
# ...          ...       ...
# 9719  165.619995  13955700
# 9720  166.160004  14190400
# 9721  164.679993  11821900
# 9722  162.850006  16407400
# 9723  161.779999  19673800
#
# [2431 rows x 8 columns]

# %% [markdown]
# ### Visualizing Features and Target Data

# %%
plt.plot(df['Open'],label='Opening Price')
plt.plot(df['Close'],label='Closing price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock price (Open vs Close Prices)')
plt.legend()
plt.show()

# %% [markdown]
# ### Model Development Process

# %%
X=df[['Open','High','Low']]
y=df[['Close']]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=42)

# %% [markdown]
# ### Creating and Training the Model

# %%
Model=LinearRegression()
Model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Make Predictions by using test data

# %%
y_pred=Model.predict(X_test)

# %% [markdown]
# ### Evaluate the Model

# %%
mse=mean_squared_error(y_pred,y_test)
r2=r2_score(y_pred,y_test)
print('MSE:',mse)
print('Accuracy:',int(r2*100),'%')
# Out:
# MSE: 0.2871668121305632
# Accuracy: 99 %

# %% [markdown]
# ### Visualizing Actual and Prdicated Data

# %%
a=np.array([i for i in range(1,488)])
plt.scatter(a,np.array(y_test),color='#4285F4',label='Acutal Price')
plt.scatter(a,np.array(y_pred),color='#0F9D58',label='Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Actual vs. Predicted Data')
plt.legend()
plt.show()

# %% [markdown]
# ### Project Summary:
#
# * Model Performance: The Linear Regression model achieved a remarkable 99% accuracy in predicting closing prices, demonstrating its effectiveness in stock price forecasting.
