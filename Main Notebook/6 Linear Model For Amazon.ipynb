# %% [markdown]
# # AMAZON Amazon.com,Inc.

# %% [markdown]
# ### Importing Necessary Libraries for Machine Learning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# ### Loading the Data

# %%
df=pd.read_csv('Data Set.csv')
df=pd.DataFrame(df)

# %%
df=df.iloc[12155:14586]
df
# Out:
#              Date Ticker        Open        High         Low       Close  \
# 12155  2015-01-02   AMZN   15.629000   15.737500   15.348000   15.426000
# 12156  2015-01-05   AMZN   15.350500   15.419000   15.042500   15.109500
# 12157  2015-01-06   AMZN   15.112000   15.150000   14.619000   14.764500
# 12158  2015-01-07   AMZN   14.875000   15.064000   14.766500   14.921000
# 12159  2015-01-08   AMZN   15.016000   15.157000   14.805500   15.023000
# ...           ...    ...         ...         ...         ...         ...
# 14581  2024-08-23   AMZN  177.339996  178.970001  175.240005  177.039993
# 14582  2024-08-26   AMZN  176.699997  177.470001  174.300003  175.500000
# 14583  2024-08-27   AMZN  174.149994  174.889999  172.250000  173.119995
# 14584  2024-08-28   AMZN  173.690002  173.690002  168.919998  170.800003
# 14585  2024-08-29   AMZN  173.220001  174.289993  170.809998  172.119995
#
#         Adj Close    Volume
# 12155   15.426000  55664000
# 12156   15.109500  55484000
# 12157   14.764500  70380000
# 12158   14.921000  52806000
# 12159   15.023000  61768000
# ...           ...       ...
# 14581  177.039993  29150100
# 14582  175.500000  22366200
# 14583  173.119995  29842000
# 14584  170.800003  29045000
# 14585  172.119995  26380000
#
# [2431 rows x 8 columns]

# %% [markdown]
# ### Visualizing Features and Target Data

# %%
plt.plot(df['Open'],label='Opening Price')
plt.plot(df['Close'],label='Closing price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Stock price (Open vs Close Prices)')
plt.legend()
plt.show()

# %% [markdown]
# ### Model Development Process

# %%
X=df[['Open','High','Low']]
y=df[['Close']]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=42)

# %% [markdown]
# ### Creating and Training the Model

# %%
Model=LinearRegression()
Model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Make Predictions by using test data

# %%
y_pred=Model.predict(X_test)

# %% [markdown]
# ### Evaluate the Model

# %%
mse=mean_squared_error(y_pred,y_test)
r2=r2_score(y_pred,y_test)
print('MSE:',mse)
print('Accuracy:',int(r2*100),'%')
# Out:
# MSE: 0.5683215455564165
# Accuracy: 99 %

# %% [markdown]
# ### Visualizing Actual and Prdicated Data

# %%
a=np.array([i for i in range(1,488)])
plt.scatter(a,np.array(y_test),color='#4285F4',label='Acutal Price')
plt.scatter(a,np.array(y_pred),color='#0F9D58',label='Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Actual vs. Predicted Data')
plt.legend()
plt.show()

# %% [markdown]
# ### Project Summary:
#
# * Model Performance: The Linear Regression model achieved a remarkable 99% accuracy in predicting closing prices, demonstrating its effectiveness in stock price forecasting.
